# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
import numpy as np

# %%
df = pd.read_csv('data/universities.csv')

# %%
df
# Out:
#                            College Name State  Public (1)/ Private (2)  \
# 0             Alaska Pacific University    AK                        2
# 1     University of Alaska at Fairbanks    AK                        1
# 2        University of Alaska Southeast    AK                        1
# 3     University of Alaska at Anchorage    AK                        1
# 4           Alabama Agri. & Mech. Univ.    AL                        1
# ...                                 ...   ...                      ...
# 1297        West Virginia State College    WV                        1
# 1298           West Virginia University    WV                        1
# 1299     West Virginia Wesleyan College    WV                        2
# 1300            Wheeling Jesuit College    WV                        2
# 1301              University of Wyoming    WY                        1
#
#       # appli. rec'd  # appl. accepted  # new stud. enrolled  \
# ...

# %%
df['% new stud. from top 10%'].agg(['mean','median'])
# Out:
# mean      25.671978
# median    21.000000
# Name: % new stud. from top 10%, dtype: float64

# %%
# Out:
# (array([[1.302e+03, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [1.302e+03, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [1.302e+03, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [1.097e+03, 1.400e+02, 3.900e+01, 1.900e+01, 6.000e+00, 0.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00],
#         [1.195e+03, 8.400e+01, 2.000e+01, 2.000e+00, 0.000e+00, 1.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [1.293e+03, 9.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [1.302e+03, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
# ...
